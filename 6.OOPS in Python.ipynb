# %% [markdown]
# `Obeject Oriented Programming`
# --

# %%
from IPython import display
display.Image ("./oops.png")

# %% [markdown]
# * Python is an object **oriented programming language**.Unlike procedure-oriented programming.
# * Where the main emphasis is on  **funtions**,objecte-oriented programming stresses on object.
# * An object is simply a collection of data(Variables) and methods (Function) that act on those data.Similary is blueprint for that object.
#
# * Almost everything in Python is an object, with its properties and methods.
#
# * A Class is like an object constructor, or a "blueprint" for creating objects.

# %% [markdown]
# Classes and objects are the two main aspects of object-oriented programming.
#
# * A class is the blueprint from  collection of objects. It is a logical entity that has some specific attributes and methods.
#
# * eg: If you have a car class, then it should contain an attribute and method viz name, standard, color, etc.
#
# * Object is anything in the real world that has some unique characteristics.It has state and behavior.
#
# * eg: Mouse, keyboard, chair, table, etc

# %%
from IPython import display
display.Image ("./class.png")

# %% [markdown]
# Each car was built from the same set of blueprints and therefore contains the same components. In object-oriented terms, we say that your car is an instance (object) of the class Car.

# %% [markdown]
# `Create a Class`
#
# Define a class in python
# Like function definitions begin with the def keywords in python, class definition begin with a class keyword.
#
# `class MyClass:
#     I'''This is docstring.Ihave created a new class'''
#     pass`

# %%
class Car:
    pass # Here the pass statement is used to indicate that this class is empty.

# %% [markdown]
# `The __init__() Method`

# %%
class Car:
    
    # initializer
    def __init__(self): # When you define __init__() in a class definition, its first parameter should be self.
                        # The self parameter refers to the individual object itself. It is used to fetch or
                        # set attributes of the particular instance.
        pass

# %% [markdown]
# self attribute
# --
#
# >The first argument of every class method is always a reference to the current instance of the class.
#
# >By convention, this argument is always named 'self'.
#
# >It is a part of Python syntax to access members of objects.
#
# >__However, self is not a reserved keyword in Python, it is just a strong convention.__

# %% [markdown]
# `Attributes`
#
# Every class you write in Python has two basic features: attributes and methods.
#
# Attributes are the individual things that differentiate one object from another. They determine the appearance, state, or other qualities of that object.
#
# In our case, the ‘Car’ class might have the following attributes:
#
# 1. Style: Sedan, SUV, Coupe
# 2. Color: Silver, Black, White
# 3. Wheels: Four

# %% [markdown]
# `Instance Attribute`
#
# The instance attribute is a variable that is unique to each object (instance). Every object of that class has its own copy of that variable. Any changes made to the variable don’t reflect in other objects of that class.
#
# In the case of our Car() class, each car has a specific color and style.

# %%
# A class with two instance attributes
class Car:

    # initializer with instance attributes
    def __init__(self, color, style):
        self.color = color
        self.style = style

# %% [markdown]
# `Class Attribute`
#
# The class attribute is a variable that is same for all objects. And there’s only one copy of that variable that is shared with all objects. Any changes made to that variable will reflect in all other objects.
#
# In the case of our Car() class, each car has 4 wheels.

# %%
# A class with one class attribute
class Car:

    # class attribute
    wheels = 4

    # initializer with instance attributes
    def __init__(self, color, style):
        self.color = color
        self.style = style

# %% [markdown]
# `Create an Object`
#
# You create an object of a class by calling the class name and passing arguments as if it were a function.

# %%
# Create an object from the 'Car' class by passing style and color
class Car:

    # class attribute
    wheels = 4

    # initializer with instance attributes
    def __init__(self, color, style):
        self.color = color
        self.style = style

c = Car('Sedan', 'Black')

# %%
# Access and modify attributes of an object
class Car:

    # class attribute
    wheels = 4

    # initializer with instance attributes
    def __init__(self, color, style):
        self.color = color
        self.style = style

c = Car('Black', 'Sedan')

# Access attributes
print(c.style)
# Prints Sedan
print(c.color)
# Prints Black

# Modify attribute
c.style = 'SUV'
print(c.style)
# Prints SUV
# Out:
# Sedan
# Black
# SUV

# %%
#Step1 Make classwith functions
class Person:
    "This is a Person class"
    age=10 # Attribute
    
    def greet(self):
        print('Hello')
#Output :10
print(Person.age)
#Classname.age

# Step2 creat a new object of person class
harry= Person()

#Step3 Calling objects greet() method
harry.greet()
# Out:
# 10
# Hello

# %% [markdown]
# **`Program to write simple class demonstration`**

# %%
class abc:   
    def show(self,a,b):        
        print("Addition is:",a+b)

a = float(input("Enter 1st number:"))
b = float(input("Enter 2nd number:"))
s = abc()
s.show(a,b)

a = float(input("Enter 1st number:"))
b = float(input("Enter 2nd number:"))
t = abc()
t.show(a,b)

# %% [markdown]
# `Private variables`
# --
#
# >Private means the attributes are only available for the members of the class not outside of the class.
#
# >A private variable can only be changed within a class method, and not outside of the class.
#
# >In Python, private variables begin with double underscores __
#
# >Unlike other programming languages, Python private variables are not strict, they can be accessed outside of the class.

# %% [markdown]
# `Method`
# >Methods are functions defined inside the body of a class. They are used to define the behaviors of an object.

# %%
# Program to use private variables
class abc:
    y = 2 # y is instance variable
    __v = 4 # v is a private variable
    def show(self):
        print("Hello from class")

s = abc()
s.show()
print(s.y)
#print(s.__v)

# %% [markdown]
# *******************************************************************************************************************************

# %% [markdown]
# `Constructors`
# --

# %%
class xyz:
    def __init__(self):
        print("Hi I am the Constructor")
        print("Bye from Constructor")
    def show(self):
        print("Hi from show.")

s = xyz()
s.show()

# %%
class xyz:
    def __init__(self,n):
        print("Hi I am the Constructor")
        print(n)
        print("Bye from Constructor")
    def show(self):
        print("Hi from show.")

s = xyz(15)
s.show()

# %% [markdown]
# `Instances a return values`
# --
#
# In Python, methods and functions can return class instances.

# %%
# Program to use instances as return values
class st:
    def add(self,a,b):
        self.a=a
        self.b=b
        return self.a+self.b

s=st()
s.add(4,3)

# %%
# Program to use instances as return values using __init__
class st:
    def __init__(self,a,b):
        self.a=a
        self.b=b
s=st(4,3)
print(s.a)
print(s.b)

# %% [markdown]
# `Instances as arguments`
# --
#
# The class instance variables are always prefixed with reserved word 'self' and typically initialized in a constructor method named __init__

# %%
class xyz:
    def __init__(self,n):
        n1 = n+1
        print(n)
        print(n1)
    def show(self):
        print("Hi from show.")

s = xyz(15)
s.show()

# %%
class xyz:
    def __init__(self,n):
        self.n1 = n+1
        print(n)
        print(self.n1)
    def show(self):
        print("Hi from show.")

s = xyz(15)
s.show()

# %%
class xyz:
    def __init__(self,n):
        self.n = n+1
        print(n)
        print(self.n)
    def show(self):
        print("Hi from show.")

s = xyz(15)
s.show()

# %% [markdown]
# `__del__()`
# --
# It is used when you want to destroy an instance of the class which is no longer referenced.

# %%
# Program to delete object of a class.

class abc:
    def __init__(self,n):
        print("Hello",n)
    def __del__(self):
        print("Object deleted.")
s1=abc("Darshan")
s2=abc("Python")

# %% [markdown]
# *****************************************************************************************************************************

# %% [markdown]
# `Inheritance`
# --
#
# * Inheritance means one object acquires properties and behavior of the parent object.
#
# * The new class is known as the Derived class or Child class.And from which inherited the properties is called as Base class or Parent class.
#
# * Inheritance provides reusability of the code.
#
# `Syntax:
# class base_class:
#     statements
# class derived_class:
#     statments`

# %% [markdown]
# `Single Inheritance`
# --

# %%
# Program to use single inheritance

class A:
    def s1(self):
        print("I am the Base class!!!")
        
class B(A):
    def s2(self):
        print("Derived class here!!!!")

o = B()
o.s2()
o.s1()

father = A()
father.s1()
father.s2()

# %%
class Person(object):
    #Consutructor
    def __init__(self,name):
        self.name =name
        
    #To get name
    def getname(self):
        return self.name
    
    # To check if this person ia an employee
    def isEmployee(self):
        return False
    
# Inherited or Subclass
class Employee(Person):
        return False
    #Here we return true
     def isEmployee(self):
        return True
    
# Driver Code
emp = Person("John") # An object of Person
print(emp,getName(),emp.isEmployee)

emp = Person("Lucy") # An object of Employee
print(emp,getName(),emp.isEmployee)

# %%
class Person():
    def __init__(self, value):
        self.hidden_name = value
    
    @property
    def name(self):
        print('Getting name:')
        return self.hidden_name

    @name.setter
    def name(self, value):
        print('Setting name to', value)
        self.hidden_name = value
        
    @name.deleter
    def name(self):
        print('Deleting name')
        del self.hidden_name

class SubPerson(Person):
    @property
    def name(self):
        print('Inside subperson getter')
        return super().name

    @name.setter
    def name(self, value):
        print('Inside subperson setter')
        super(SubPerson, SubPerson).name.__set__(self, value)

    @name.deleter
    def name(self):
        print('Inside subperson deleter')
        super(SubPerson, SubPerson).name.__delete__(self)

# %% [markdown]
# `Multiple Inheritance`
# --
# * Base1,Base2 -> Derived

# %%
# Program to use Multiple inheritance
class st1:
    def num1(self):
        self.n1=7
        print("num1: ",self.n1)
class st2:
    def num2(self):
        self.n2=10
        print("num2: ",self.n2)

class st(st1,st2):
    def add(self):
        return self.n1+self.n2
  
s=st()
s.num1()
s.num2()
print(s.add())

# %% [markdown]
# ***************************************************************************************

# %% [markdown]
# `Polymorphism`
# --
# Polymorphism ia an ability to use a common interface for multiple form(data types).

# %%
class Parrot:
    def fly(self):
        print("Parrot can fly")
        
    def swim(self):
        print("Parrot can't swim')
            
class Penguin:
              
    def fly(self):
        print("Parrot can't fly")
        
    def swim(self):
        print("Parrot can swim')
              
# Common interface
def flying_test(bird):
    bird.fly()
    
# instatiate objects
blue = Parrot()
peggy= Penguin()

              
# Passing the object
flying_test(blue)
flying_test(peggy)

# %%
* In the above program,we defined two classes Parrot and Peguin.
* Each of them have common fly() method.However,their function are different.

# %% [markdown]
# `Encapsulation`
# --
# Using OOP in python,we can restrict access to method and varibales.
# This prevent data form direct modification which is called encapsulation.

# %%
class Computer:
    def __init__(self):
        self._maxprice =900
        
    def sell(self):
        print("selling Price:{}".format(self._maxprice))
c = Computer()
c.sell()

#Change the price
c._maxprice =100
c.sell()

# %% [markdown]
# `Happy Learning`
# --
